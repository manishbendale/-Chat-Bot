# %% [markdown]
# <a href="https://colab.research.google.com/github/manishbendale/-Chat-Bot/blob/main/FSDS_Working_with_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Working with Images**

# %%
import skimage.io as io #for input output manipulations on the image
import matplotlib.pyplot as plt
import numpy as np



#you can download any color image from google.com to use for this lab


# Read the image
img = io.imread('/content/girl.jpeg')

plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (224, 236, 3)

# %%
# Split
red = img[:, :, 0] #we take all height and with of our image and for the channel, we take the first one here
green = img[:, :, 1]  #we take all height and with of our image and for the channel, we take the second one here
blue = img[:, :, 2]    #we take all height and with of our image and for the channel, we take the third one here

# %%
plt.imshow(red, cmap="Reds")
plt.show()

# %%
plt.imshow(green, cmap="Greens")
plt.show()

# %%
plt.imshow(blue, cmap="Blues")
plt.show()

# %%
#!pip install Pillow

# %%
from PIL import Image
img = Image.open('/content/girl.jpeg').convert('L')
img.save('greygirl.png')

# %%
import skimage.io as io #for input output manipulations on the image
import matplotlib.pyplot as plt
import numpy as np

# Read the image
img2 = io.imread('/content/greygirl.png')

plt.imshow(img2, cmap="Greys_r")
plt.show()

# %%
img.shape
# Out:
# (224, 236)

# %%
import tensorflow as tf
transformation = tf.keras.preprocessing.image.apply_affine_transform(
img,
theta=270
)
plt.imshow(transformation)

# %%
# zx: Zoom in x direction.
# zy: Zoom in y direction

transformation = tf.keras.preprocessing.image.apply_affine_transform(img,zx=0.5,zy= 0.5)
plt.imshow(transformation)

# %%
# tx: Width shift.
# ty: Height shift.

transformation = tf.keras.preprocessing.image.apply_affine_transform(
img,
tx=50,
ty=1,
)
plt.imshow(transformation)

# %%
img = io.imread('/content/image.png')

plt.imshow(img)
plt.show()

# %%
import tensorflow as tf
transformation = tf.keras.preprocessing.image.apply_affine_transform(
img,
tx=500,
ty=500,
)
plt.imshow(transformation)

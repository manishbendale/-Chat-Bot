# %% [markdown]
# <a href="https://colab.research.google.com/github/manishbendale/-Chat-Bot/blob/main/Scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #**Scipy**
#
# SciPy (pronounced “Sigh Pie”) is a Python-based ecosystem of open-source software for mathematics, science, and engineering. Normally called SciPy stack. In particular, these are some of the core packages:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**What is SciPy?**

# %% [markdown]
# The SciPy library is one of the core packages that make up the SciPy stack. It provides many user-friendly and efficient numerical routines, such as routines for numerical integration, interpolation, optimization, linear algebra, and statistics.
#
#
# SciPy is a free and open-source Python library.
# It is a collection of mathematical algorithms and convenience functions built on the NumPy extension of Python. It adds significant power to the interactive Python session by providing the user with high-level commands and classes for manipulating and visualizing data.

# %% [markdown]
# ##**Installing SciPy**

# %%
# !pip install scipy

# %% [markdown]
# <br>
#
# **In Anaconda**

# %%
conda install –c anaconda scipy

# %% [markdown]
# <br>
#
# **Import SciPy**

# %%
import scipy

# %% [markdown]
# ##**Sub packages in SciPy**

# %% [markdown]
# The following table shows some of the modules or sub-packages that can be used in **SciPy** for computing:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example:
#
# ##**SciPy linalg**

# %% [markdown]
# Solve Linear Equations
#
#   x + 2y - 3z = -3
#
#   2x - 5y + 4z = 13
#
#   5x + 4y - z = 5
#
#
# We will find values of x,y and z for which all these equations are zero.
# Also finally we will check if the values are right by substituting them
# in the equations

# %%
import numpy as np  
from scipy import linalg  
 
# Creating input array  
a = np.array([[1, 2, -3], [2, -5, 4], [5, 4, -1]])  

# Solution Array  
b = np.array([[-3], [13], [5]])  

# Solve the linear algebra  
x = linalg.solve(a, b)  
# Print results  

print(x)  
# Checking Results  
print("\n We get all zeros below")  
print(a.dot(x) - b)
# Out:
# [[ 2.]
#  [-1.]
#  [ 1.]]
#
#  We get all zeros below
# [[0.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## **SciPy Ndimage**

# %%
import scipy.misc
import matplotlib.pyplot as plt
face = scipy.misc.face()#returns an image of raccoon
# #display image using matplotlib
plt.imshow(face)
plt.show()

# %%
from scipy import misc,ndimage
import matplotlib.pyplot as plt
face = misc.face()
rotate_face = ndimage.rotate(face, 170)
plt.imshow(rotate_face)
plt.show()

# %%
import scipy.misc
import matplotlib.pyplot as plt
face = scipy.misc.face()#returns an image of raccoon
# lx,ly,channels= face.shape

# # Cropping
crop_face = face[int(lx/6):int(-lx/6), int(ly/6):int(-ly/6)]
plt.imshow(crop_face)
plt.show()

# %% [markdown]
# We will see more of Scikit-learn in the [Machine Learning class](https://www.udemy.com/course/data-science-and-machine-learning-projects-mastery/?referralCode=AF7865ACCACC24F02082)
